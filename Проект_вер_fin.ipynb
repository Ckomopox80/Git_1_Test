# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Привет, Денис! Поздравляю с выполнением очередного проекта!!</b>
#
# Меня зовут Петр Раздобреев и я буду проверять твою работу. Попробую помочь сделать тебе её еще лучше! В Практикуме принято общени на ты, но если это дискомфортно, то сообщи об этом)
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>☁️Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️ Так выделены небольшие замечания.Такие замечания в проекте допустимы, это пространство для улучшений в будущем.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️Так я выделяю успешные идеи.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Петр, добрый день.
# <br>Спасибо большое Вам за ваши замечания, они помогают мне лучше освоить предмет)))
# <br>Постааюсь ответить верно на все Ваши критические замечания!!.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v2:</b>☀️
#
# Здравствуй, Денис, спасибо за такую оценку работы, благодарю!
#
# </div>

# %% [markdown]
# # Проект: Статистический анализ данных

# %% [markdown]
# ## Описание проекта.
# Вы аналитик популярного сервиса аренды самокатов GoFast. Вам передали данные о некоторых пользователях из нескольких городов, а также об их поездках.
#
# Чтобы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться:
# - без подписки
#     - абонентская плата отсутствует;
#     - стоимость одной минуты поездки — 8 рублей;
#     - стоимость старта (начала поездки) — 50 рублей;
# - с подпиской Ultra
#     - абонентская плата — 199 рублей в месяц;
#     - стоимость одной минуты поездки — 6 рублей;
#     - стоимость старта — бесплатно.

# %% [markdown]
# ## Цели проекта и Гипотезы.
#
# <br>**Цели.**
# <br>Проанализируйте данные и проверьте некоторые гипотезы, которые могут помочь бизнесу вырасти.
# <br>
# <br>**Гипотезы.**
# <br>Продакт-менеджеры сервиса хотят увеличить количество пользователей с подпиской. Для этого они будут проводить различные <br>акции, но сначала нужно выяснить несколько важных моментов.
# - Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.
# - Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров? Проверьте гипотезу и сделайте выводы.
# - Проверьте гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. Сделайте вывод.
# - Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# ## Описание данных.

# %% [markdown]
# **Пользователи — `users_go.csv`**
#
# - `user_id`	— уникальный идентификатор пользователя
# - `name` — имя пользователя
# - `age` —	возраст
# - `city` — город
# - `subscription_type` — тип подписки (free, ultra)
#
# **Поeздки — `rides_go.csv`**
#
# - `user_id`	— уникальный идентификатор пользователя
# - `distance` — расстояние, которое пользователь проехал в текущей сессии (в метрах)
# - `duration` — продолжительность сессии (в минутах) — время с того момента, как пользователь нажал кнопку «Начать поездку» до момента, как он нажал кнопку «Завершить поездку»
# - `date` — дата совершения поездки
#
# **Подписки — `subscriptions_go.csv`**
#
# - `subscription_type` — тип подписки
# - `minute_price` — стоимость одной минуты поездки по данной подписке
# - `start_ride_price` — стоимость начала поездки
# - `subscription_fee` — стоимость ежемесячного платежа

# %% [markdown]
# ## Основные шаги проекта.
#
#     - Шаг 1. Загрузка данных;
#     - Шаг 2. Предобработка данны;
#     - Шаг 3. Исследовательский анализ данных;
#     - Шаг 4. Объединение данных;
#     - Шаг 5. Подсчёт выручки;
#     - Шаг 6. Проверка гипотез;
#     - Шаг 7 (необязательное задание). Распределения;
#     - Шаг 8. Общий вывод.

# %% [markdown]
# ## Реализация проекта.

# %% [markdown]
# ### ШАГ 0. Загрузка и настройка библиотек.

# %% [markdown]
# #### Загрузка библиотек.

# %%
# Датасеты
import pandas as pd

# визуализация данных
import plotly.express as px

# Математика
import numpy as np
from scipy import stats as st

# Графики
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import rcParams, rcParamsDefault
import seaborn as sns

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️
#
#
# Перед отправкой лучше нажимать `Kernel`/`Restart & Run All`, чтобы исключить возможность казусов с незапуском каких-то ячеек. ![image.png](attachment:image.png) </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Поторопился, буду исправляться!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий Мой ☀️
#
# Отлично!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# </div>

# %% [markdown]
# #### Дополнительные настройки.

# %%
# Настройки отображения
pd.options.display.float_format = '{:,.2f}'.format
pd.options.mode.chained_assignment = None
sns.set_style('darkgrid')

# Отображение колонок.
pd.options.display.max_columns = 20

# Для нормального отображения графиков plt
rcParams['figure.figsize'] = 10, 6
# %config InlineBackend.figure_format = 'svg'

# Копирование значений, а не ссылок, через b = copy.deepcopy(a)
import copy

# Отображение всех колонок при выводе на печать
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Шаг 1. Загрузка данных.

# %% [markdown]
# #### Загрузка данных. Таблица с пользователями  "users_go".

# %%
# Загружаем данные.
try:
    users_go = pd.read_csv('/datasets/users_go.csv')
except:
    users_go = pd.read_csv('https://code.s3.yandex.net/datasets/users_go.csv')

# %%
# Изучение датафрейма 'users_go' 
users_go.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 412.6 KB

# %%
# Выводим описательную статистику
users_go.describe()
# Out:
#        user_id      age
# count 1,565.00 1,565.00
# mean    762.63    24.92
# std     443.26     4.55
# min       1.00    12.00
# 25%     378.00    22.00
# 50%     762.00    25.00
# 75%   1,146.00    28.00
# max   1,534.00    43.00

# %%
# Посмотрим таблицу
users_go.sample(10, random_state=0)
# Out:
#       user_id      name  age            city subscription_type
# 319       320    Оксана   30    Екатеринбург             ultra
# 1405     1406  Вероника   28  Ростов-на-Дону              free
# 644       645     Олеся   36       Краснодар             ultra
# 579       580  Вероника   31       Пятигорск             ultra
# 414       415    Юлиана   24       Пятигорск             ultra
# 494       495  Святогор   24            Омск             ultra
# 618       619  Кристина   29    Екатеринбург             ultra
# 1479     1480      Кира   25       Краснодар              free
# 1263     1264  Каролина   21       Пятигорск              free
# 530       531    Елисей   22            Сочи             ultra

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Спасибо, что фиксируешь `random_state`, воспроизводимость кода - полезное свойство !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# Посмотрим в разрезе гистограмм.
users_go.hist()
# Out:
# array([[<AxesSubplot:title={'center':'user_id'}>,
#         <AxesSubplot:title={'center':'age'}>]], dtype=object)

# %% [markdown]
# ##### Столбец 'user_id'

# %%
# Уникальные идентификаторы
print(len(users_go['user_id'].unique()), 'уникальных значений из', users_go['user_id'].count(), 'строк')
print('От', users_go['user_id'].min(), 'до', users_go['user_id'].max())
# Out:
# 1534 уникальных значений из 1565 строк
# От 1 до 1534

# %% [markdown]
# 1534 уникальных значений из 1565 строк.
# <br>От 1 до 1534
# <br>В ‘user_id’ обнаружены дубликаты идентификаторов.
# <br>Имеющиеся значения позволяют использовать для этого столбца тип данных ‘uint16’.

# %% [markdown]
# ##### Столбец 'age'

# %%
# Уникальные возрасты
print(len(users_go['age'].unique()), 'уникальных значений из', users_go['age'].count(), 'строк')
print('От', users_go['age'].min(), 'до', users_go['age'].max())
# Out:
# 29 уникальных значений из 1565 строк
# От 12 до 43

# %% [markdown]
# 29 уникальных значений из 1565 строк.
# <br>От 12 до 43
# <br>Данные в столбце ‘age’ позволяют использовать для него тип данных ‘uint8’.

# %% [markdown]
# ##### Столбец 'city'

# %%
# Уникальные названия населенных пунктов
users_go['city'].unique()
# Out:
# array(['Тюмень', 'Омск', 'Москва', 'Ростов-на-Дону', 'Краснодар',
#        'Пятигорск', 'Екатеринбург', 'Сочи'], dtype=object)

# %% [markdown]
# Неявные дубликаты в столбце ‘city’ не обнаружены.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий Мой ☀️
#
# Отлично!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Шалом Шалом!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# </div>

# %%
# Кол-во уникальных городов.
count_users_by_city = users_go['city'].value_counts()
count_users_by_city
# Out:
# Пятигорск         226
# Екатеринбург      206
# Ростов-на-Дону    202
# Краснодар         196
# Сочи              192
# Омск              186
# Тюмень            185
# Москва            172
# Name: city, dtype: int64

# %% [markdown]
# ##### Столбец 'subscription_type'

# %%
# Уникальные типы
users_go['subscription_type'].unique()
# Out:
# array(['ultra', 'free'], dtype=object)

# %%
# Посмотрим на явные дубликаты
users_go.duplicated().sum()
# Out:
# 31

# %%
# Кол - во уникальных типов.
count_sub = users_go['subscription_type'].value_counts()
count_sub
# Out:
# free     846
# ultra    719
# Name: subscription_type, dtype: int64

# %% [markdown]
# **Промежуточный вывод:**
# <br>Датафрейм ‘users_go’ имеет 5 столбцов и 1565 строк без пропусков и выбросов, имеется 31 явный дубликат. Типы столбцов <br>‘user_id’, ‘age’, ‘subscription_type’ имеют не оптимальные типы данных, их корректировка может снизить вес датафрейма. <br>Названия столбцов соответствуют ‘змеиному’ стилю. Есть дубликаты идентификаторов в столбце ‘user_id’.

# %%
# Изучение датафрейма 'users_go' 
users_go.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 458.7 KB

# %% [markdown]
# #### Загрузка данных. Таблица с поездками  "rides_go".

# %%
# Чтение данных
try:
    rides_go = pd.read_csv('/datasets/rides_go.csv') 

except:
    rides_go = pd.read_csv('datasets/rides_go.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       2 try:
# ----> 3     rides_go = pd.read_csv('/datasets/rides_go.csv')
#       5 except:
#
# File c:\Users\User\anaconda3\envs\practicum\lib\site-packages\pandas\io\parsers.py:610, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️
#
# Конечно с точки зрения правильности лучше в одном блоке `try-except` проверять одно действие, но ведь у нас либо откроются все датафреймы по одному пути, либо по другому, в связи с этим можно обойтись одним блоком
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Надо было всё сразу загрузить?"
# <br>Так?
# <br>users_go,rides_go,subscriptions_go = (pd.read_csv('/datasets/users_go.csv'),
#                                <br> pd.read_csv('/datasets/rides_go.csv'),
#                                 <br>pd.read_csv('/datasets/subscriptions_go.csv'))
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v2:</b>☀️
#
# Можно так с оговоркой, что точно либо один, либо другой путь верен
#
# </div>

# %%
# Изучение датафрейма 'rides_go' 
rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %%
# Выводим описательную статистику
rides_go.describe()
# Out:
#         user_id  distance  duration
# count 18,068.00 18,068.00 18,068.00
# mean     842.87  3,070.66     17.81
# std      434.73  1,116.83      6.09
# min        1.00      0.86      0.50
# 25%      487.00  2,543.23     13.60
# 50%      889.00  3,133.61     17.68
# 75%    1,213.25  3,776.22     21.72
# max    1,534.00  7,211.01     40.82

# %%
# Посмотрим таблицу
rides_go.sample(10, random_state=0)
# Out:
#        user_id  distance  duration        date
# 13671     1222  2,436.48     18.22  2021-04-16
# 1644       176  3,791.38     25.22  2021-08-10
# 2330       248  3,286.88     18.59  2021-08-28
# 2777       296  3,231.42     18.23  2021-06-22
# 4172       450  4,160.65     17.25  2021-06-07
# 7450       767    684.37      4.58  2021-11-25
# 5412       578  2,947.91     15.05  2021-08-24
# 9045       890  2,614.21     14.23  2021-08-22
# 17280     1480  2,471.20     22.59  2021-02-06
# 5063       545  3,383.69     20.25  2021-01-07

# %%
# Посмотрим в разрезе гистограмм.
rides_go.hist()
# Out:
# array([[<AxesSubplot:title={'center':'user_id'}>,
#         <AxesSubplot:title={'center':'distance'}>],
#        [<AxesSubplot:title={'center':'duration'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# **Промежуточный вывод:**
# <br>В датафрейме ‘rides_go’ обнаружены 4 столбца и 18068 строк без пропусков и выбросов. Вес датафрейма 564.8 Кб. Типы столбцов <br>‘user_id’ и ‘date’ не оптимальны. Корректировка типов этих столбцов снизит потребление памяти и позволит раскрыть их <br>потенциал. Названия столбцов соответствуют ‘змеиному’ стилю. Возможно наличие выбросов в столбцах ‘distance’ и ‘duration’.

# %% [markdown]
# #### Загрузка данных. Таблица с подписками "subscriptions_go ".

# %%
# Чтение данных
try:
    subscriptions_go = pd.read_csv('/datasets/subscriptions_go.csv') 
except:
    subscriptions_go = pd.read_csv('datasets/subscriptions_go.csv')

# %%
subscriptions_go.describe()
# Out:
#        minute_price  start_ride_price  subscription_fee
# count          2.00              2.00              2.00
# mean           7.00             25.00             99.50
# std            1.41             35.36            140.71
# min            6.00              0.00              0.00
# 25%            6.50             12.50             49.75
# 50%            7.00             25.00             99.50
# 75%            7.50             37.50            149.25
# max            8.00             50.00            199.00

# %%
# Изучение датафрейма 'subscriptions_go' 
subscriptions_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %%
# Посмотрим таблицу
subscriptions_go.head()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %%
# Посмотрим дубликаты.
subscriptions_go.isna().sum().sort_values()
# Out:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# И про дубликаты не забываешь, замечательно. Но действия по первичному анализу датафреймов схожи, можно было бы функцию написать

# %% [markdown]
# **Промежуточный вывод:**
# <br>В датафрейме обнаружены 4 столбца и 2 строки без пропусков и выбросов. Не оптимальные типы данных во всех столбцах. Это не <br>является критичным при весе датафрейма в 192 байта. Если тип данных в столбце ‘subscription_type’ датафрейма ‘users_go’ <br>будет изменён, то и в данном датафрейме одноимённый столбец требуется привести в соответствие. Названия столбцов <br>соответствуют ‘змеиному’ стилю.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Корректировка данных в таблицах.

# %%
# Корректировка столбца 'date' в датафейме 'rides_go'
rides_go['date'] = pd.to_datetime(rides_go['date']).dt.date

# %%
# Посмотрим таблицу
rides_go.sample(10, random_state=0)
# Out:
#        user_id  distance  duration        date
# 13671     1222  2,436.48     18.22  2021-04-16
# 1644       176  3,791.38     25.22  2021-08-10
# 2330       248  3,286.88     18.59  2021-08-28
# 2777       296  3,231.42     18.23  2021-06-22
# 4172       450  4,160.65     17.25  2021-06-07
# 7450       767    684.37      4.58  2021-11-25
# 5412       578  2,947.91     15.05  2021-08-24
# 9045       890  2,614.21     14.23  2021-08-22
# 17280     1480  2,471.20     22.59  2021-02-06
# 5063       545  3,383.69     20.25  2021-01-07

# %%
print('Минимальная дата:', rides_go['date'].min())
print('Максимальная дата:',  rides_go['date'].max())
# Out:
# Минимальная дата: 2021-01-01
# Максимальная дата: 2021-12-30

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Отличная привычка проверять даты набора

# %% [markdown]
# #### Добавление столбца 'month' в rides_go.

# %%
# Добавление столбца 'month' с номером месяца в датафейм 'rides_go'
rides_go['month'] = pd.DatetimeIndex(rides_go['date']).month

# %%
# Посмотрим таблицу
rides_go.head()
# Out:
#    user_id  distance  duration        date  month
# 0        1  4,409.92     25.60  2021-01-01      1
# 1        1  2,617.59     15.82  2021-01-18      1
# 2        1    754.16      6.23  2021-04-20      4
# 3        1  2,694.78     18.51  2021-08-11      8
# 4        1  4,028.69     26.27  2021-08-28      8

# %% [markdown]
# #### Прверка дубликатов в 'users_go'.

# %%
# Проверка наличия дубликатов в 'users_go'
users_go.sort_values(by='user_id').loc[users_go['user_id'].duplicated() == True].count()
# Out:
# user_id              31
# name                 31
# age                  31
# city                 31
# subscription_type    31
# dtype: int64

# %%
# Удаление дубликатов идентификаторов в столбце 'user_id' датафрейма 'users_go'
users_go = users_go.sort_values(by='user_id').loc[users_go['user_id'].duplicated() == False]

# %%
# Повторная проверка наличия дубликатов в 'users_go'
users_go.sort_values(by='user_id').loc[users_go['user_id'].duplicated() == True].count()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
# Датафейм 'users_go'
users_go.info()
users_go.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 71.9+ KB
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %% [markdown]
# **Промежуточный вывод**
# <br>Предобработка датафрейма сократила количество строк в нем с 1565 до 1534, а его вес почти в 10 раз с 412.6 Кб до 41.9 Кб.

# %% [markdown]
# #### Анализ дат в 'rides_go'.

# %%
rides_go['date'].head(10)
# Out:
# 0    2021-01-01
# 1    2021-01-18
# 2    2021-04-20
# 3    2021-08-11
# 4    2021-08-28
# 5    2021-10-09
# 6    2021-10-19
# 7    2021-11-06
# 8    2021-11-14
# 9    2021-11-22
# Name: date, dtype: object

# %%
# Датафейм 'rides_go'
print(rides_go.info())
print()
print(rides_go.head())
print()
print(rides_go.describe())
print()
print('Анализ дат:')
print('Минимальная дата :', rides_go['date'].min())
print('Максимальная дата:', rides_go['date'].max())
rides_go['date'].hist()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
#  4   month     18068 non-null  int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 705.9+ KB
# None
#
#    user_id  distance  duration        date  month
# 0        1  4,409.92     25.60  2021-01-01      1
# 1        1  2,617.59     15.82  2021-01-18      1
# 2        1    754.16      6.23  2021-04-20      4
# 3        1  2,694.78     18.51  2021-08-11      8
# 4        1  4,028.69     26.27  2021-08-28      8
#
#         user_id  distance  duration     month
# count 18,068.00 18,068.00 18,068.00 18,068.00
# mean     842.87  3,070.66     17.81      6.49
# std      434.73  1,116.83      6.09      3.44
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️
#
# Важно подписывать оси, заголовок добавлять
# </div>

# %% [markdown]
# **Промежуточный вывод**
# <br>В процессе предобработки данных в датафрейме ‘rides_go’ был добавлен столбец ‘month’ и изменены типы данных столбцов. В <br>результате вес датафрейма вырос с 564.8 Кб до 705.9 Кб. Однако, без корректировки типов данных, вес датафрейма был бы еще <br>больше. Также проверены данные в столбце с датами. Диапазон дат с 01.01.2021 по 30.12.2021. В пределах этого диапазона дат <br>количество значений относительно равномерно распределено.

# %%
# Датафейм 'subscriptions_go'
subscriptions_go.info()
subscriptions_go.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %% [markdown]
# **Промежуточный вывод**
# <br>Предобработка датафрейма сократила его вес.

# %% [markdown]
# #### Вывод по Предобработке данных.
# Пропущенных данных в таблицах нет.
# <br>Дубликаты имеются среди пользователей, удалили строки-дубликаты.
# <br>Добавили столбец `month` с номер месяца.

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# #### Частота встречаемости городов.

# %%
# Посмотрим уникальные города
count_users_by_city = users_go['city'].value_counts()

# %%
count_users_by_city
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %%
plt.hist(users_go['city'], bins = 10)
plt.title('Распределение пользователей по городам')
plt.xlabel('')
plt.ylabel('Количество пользователей по городам')
plt.grid()
plt.show()

# %%
count_users_by_city['rate'] = round(users_go['city'].value_counts() / 
                                    count_users_by_city.sum(), 2) * 100

# %%
# Посмотрим распределение пользователей в процентном соотношении
count_users_by_city['rate']
# Out:
# Пятигорск        14.00
# Екатеринбург     13.00
# Ростов-на-Дону   13.00
# Краснодар        13.00
# Сочи             12.00
# Омск             12.00
# Тюмень           12.00
# Москва           11.00
# Name: city, dtype: float64

# %%
# Инное отображение.Посмотрим 'Распределение пользователей по городам'
users_go['city'].value_counts().plot(
    kind = 'pie', 
    y = count_users_by_city,
    autopct = '%1.0f%%',
    figsize=(7,7), 
    title = 'Распределение пользователей по городам');

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️
#
# Секторов многовато, тяжело читать визуализацию, рекомендую когда более 5-6 категорий использовать столбчатую диаграмму
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Добавил выше!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v2:</b>☀️
#
#
# Спасибо, только порекомендовал бы с числом `bins` поработать, лучше чтобы либо были пропуски между всеми столбцами, либо вообще без них
# </div>

# %% [markdown]
# **Промежуточный вывод:**
# <br>Лидером по частотности является Пятигорск (219 строк).
# <br>Далее идут Екатеринбург (204 строки) и Ростов-на-Дону (198 строк).
# <br>Меньше всего — Москва (168 строк).

# %% [markdown]
# #### Соотношение пользователей в зависимости от тарифа.

# %%
count_sub = users_go['subscription_type'].value_counts()

# %%
count_sub
# Out:
# free     835
# ultra    699
# Name: subscription_type, dtype: int64

# %%
# Посмотрим 'Процентное соотношение пользователей в зависимости от тарифа'
users_go['subscription_type'].value_counts().plot(
    kind = 'pie', 
    y = count_sub, 
    autopct = '%1.0f%%', 
    figsize=(5,5),
    title = 'Процентное соотношение пользователей в зависимости от тарифа');

# %% [markdown]
# **Промежуточный вывод:**
# <br>Пользователей с подпиской «free» всего 835, что составляет 54% от общего количества и на 136 больше, чем с подпиской «ultra».

# %% [markdown]
# #### Возраст пользователей

# %%
plt.hist(users_go['age'], bins = 30)
plt.title('Возраст пользователей')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Самые младшие пользователи

# %%
users_go['age'].sort_values().head(10)
# Out:
# 664     12
# 66      12
# 727     12
# 34      12
# 235     13
# 1249    13
# 314     13
# 83      13
# 553     13
# 1241    13
# Name: age, dtype: int64

# %% [markdown]
# Самые старшие пользователи

# %%
users_go['age'].sort_values(ascending=False).head(10)
# Out:
# 1201    43
# 961     39
# 804     38
# 453     38
# 383     38
# 205     37
# 848     37
# 721     36
# 1491    36
# 644     36
# Name: age, dtype: int64

# %% [markdown]
# **Промежуточный вывод:**
# <br>Услугами сервиса аренды самокатов пользуются люди от 12 до 43 лет. Распределение возрастной кривой имеет нормальное <br>распределение. Максимальное количество пользователей в возрасте 25 лет, этот же возраст является медианным.
#
# - Основные пользователи - люди от 20 до 30 лет
# - Распределение пользователей по городам +- одинаковое:
#     - Наибольшее количество пользователей в Пятигорске
#     - Наименьшее в Москве
# - Преобладают пользователи с бесплатным тарифом (54%)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Есть акцент и на довольно юных пользователях, кстати здесь вопрос, а законадательно возможно ли это. Такие факты хорошо бы проверять, выходя чуть за рамки непосредственно задания

# %% [markdown]
# #### Расстояние, которое пользователь преодолел за одну поездку

# %%
plt.hist(rides_go['distance'], bins = 40)
plt.title('Расстояние поездок')
plt.xlabel('Дистанция, м')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Наличие пары пиков дистанций наталкивает на мысль, что может быть несколько сценариев пользования приложением и с этими категориями стоит отдельно работать

# %% [markdown]
# Самые короткие дистанции за одну поездку:

# %%
round(rides_go['distance'].sort_values(), 2).head(10)
# Out:
# 11555    0.86
# 9541     2.57
# 13690    4.33
# 8658     6.78
# 7841     7.10
# 8906    11.28
# 8324    12.23
# 13940   15.00
# 15626   15.37
# 11862   15.63
# Name: distance, dtype: float64

# %% [markdown]
# Самые длинные дистанции за одну поездку:

# %%
round(rides_go['distance'].sort_values(ascending=False), 2).head(10)
# Out:
# 16309   7,211.01
# 16484   7,066.00
# 15580   6,908.49
# 17171   6,760.94
# 17242   6,724.93
# 10341   6,671.97
# 11385   6,601.20
# 12086   6,538.94
# 10915   6,535.39
# 11319   6,503.60
# Name: distance, dtype: float64

# %%
# Посмотрим выбросы
sns.boxplot(x=rides_go['distance'], color='blue')
plt.title('Расстояние, преодоленное за одну поездку')
plt.xlabel('Расстояние, м')
_ = plt.xlim(0, 8000)

# %% [markdown]
# **Промежуточный вывод:**
# <br>За одну поездку пользователи преодолевают от 1 до 7211 метров. Медиана всех значений равна 3134 метров. Наблюдаются два <br>пика. Малый пик около 700 метров, большой пик около 3200 метров. Между пиками значения нормально распределены.

# %% [markdown]
# #### Продолжительность поездок

# %% [markdown]
# Посмотрим на продолжительность поездок пользователей:

# %%
plt.hist(rides_go['duration'], bins = 40)
plt.title('Продолжительность поездок')
plt.xlabel('Время поездки, м')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Самые короткие поездки:

# %%
rides_go['duration'].sort_values().head(10)
# Out:
# 12013   0.50
# 17314   0.50
# 15029   0.50
# 7437    0.50
# 12967   0.50
# 15015   0.50
# 13012   0.50
# 7508    0.50
# 16589   0.50
# 9049    0.50
# Name: duration, dtype: float64

# %% [markdown]
# Самые долгие поездки:

# %%
rides_go['duration'].sort_values(ascending=False).head(10)
# Out:
# 4215   40.82
# 4709   39.87
# 2623   39.53
# 1998   38.35
# 6453   38.27
# 143    38.13
# 3729   37.01
# 499    36.91
# 6348   36.81
# 4653   36.62
# Name: duration, dtype: float64

# %% [markdown]
# Общее время поездок и дистанция для каждого пользователя:

# %%
rides_go.groupby(['user_id']).sum(numeric_only = True)
# Out:
#          distance  duration  month
# user_id
# 1       34,070.18    204.60     99
# 2       33,964.06    197.64     67
# 3       36,907.60    233.19     66
# 4       44,837.19    288.56    107
# 5       35,556.95    174.07     51
# ...           ...       ...    ...
# 1530    46,758.47    292.37    104
# 1531    67,054.79    408.19    142
# 1532    33,902.20    212.16    111
# 1533    36,890.19    240.58     65
# 1534    41,898.44    229.84    100
#
# [1534 rows x 3 columns]

# %%
# Посмотрим выбросы
sns.boxplot(x = rides_go['duration'], color='blue')
plt.title('Время, проведенное в поездке')
plt.xlabel('Время, минуты')
_ = plt.xlim(0, 45)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>☁️
#
# Красным, так как критически хочу обратить внимание на этот аспект.
#
# Генерировать гипотезы, которые объясняют закономерности, аномалии - отличное стремление. Но если то, что ты предполагаешь можно проверить по имеющимся данным, то лучше сначала проверять, а потом утверждать, чтобы не подталкивать к неверным выводам.
#
#
# Здесь это про расстояние крайне коротких по времени поездок
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Удалил......
# <br>Промежуточный вывод:
# <br>Продолжительность поездок нормально распределена от 0 до 41 минуты. Продолжительность в 18 минут является как наиболее <br>распространенной так и медианным значением.
# <br>Наблюдается анамалия размером менее 100 поездок с продолжительностью в 1 минуту. Однако, они не являются выбрасами, т.к. <br>подкреплены данными о поездках со столь же маленькими дистанциями.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера v2:</b>⛅️
#
# Ниже вывожу распределение дистанции таких сверх коротких по времени поездок и как раз вижу то, к чему хотел привлечь твоё внимание. Дистанции крайне внушительны
# </div>

# %%
# Код ревьюера
rides_go.query('duration == 0.5')['distance'].describe()
# Out:
# count      95.00
# mean    5,113.18
# std       658.25
# min     4,030.31
# 25%     4,611.51
# 50%     5,052.77
# 75%     5,488.46
# max     7,211.01
# Name: distance, dtype: float64

# %% [markdown]
# #### Вывод по исследовательскому анализу данных.
# **Частота встречаемости городов**
#
# Количество пользователей по городам распределено примерно одинаково, нет выдающихся значений. Лидером по количеству пользователей является Пятигорск - 219 пользователей. Меньше всего пользователей в Москве - 168. Связано это скорее всего с тем, что Пятигорск по размерам в несколько раз меньше Москвы, т.е. в Пятигорске удобнее брать самокат, чтобы куда-то добраться.
#
# **Соотношение пользователей с подпиской и без подписки**
#
# Пользователей, использующих бесплатную подписку больше - 835 человек, что является ~54% от общего числа пользователей.
# На платной подписке сидит 699 пользователей, что соответственно является ~46%.
#
# **Возраст пользователей**
# <br>Услугами сервиса аренды самокатов пользуются люди от 12 до 43 лет. Максимальное количество пользователей в возрасте 25 лет, <br>этот же возраст является медианным. В основном, пользователи приложения укладываются в промежуток от 20 до 30 лет.
# - Самыми младшими являются пользователи 12, 13 лет.
# - Самыми старшими - 43, 39.
#
#
# **Расстояние, которое пользователь преодолел за одну поездку**
# Малый пик около 700 метров, большой пик около 3200 метров. Между пиками значения нормально распределены.
# - Самая короткая дистанция - 0.86 км
# - Самая длинная - 7.2 км
#
# В основном пользователи проезжают от 2.5 км до 4 км.
#
# **Продолжительность поездок**
#
# - Самые короткие поездки - по пол минуты. Выглядят крайне странно, возможно пользователи просто передумали пользоваться самокатом. Либо же техническая неинсправность самого самоката.
# - Самая длинная поездка заняла 40 минут.
#
# В основном же длительность поездки состовляет 13 - 22 минут.

# %% [markdown]
# ### Шаг 4. Объединение данных

# %% [markdown]
# #### Объеденение данных о пользователях, поездах и подписчиках в один датафрейм методом MERGE()

# %% [markdown]
# **Объединим данные о пользователях, поездках и подписках в один датафрейм.**

# %%
full_data = users_go.merge(rides_go, on = 'user_id')
full_data = full_data.merge(subscriptions_go, on = 'subscription_type')

# %%
display(full_data.sample(5))
# Out:
#        user_id     name  age            city subscription_type  distance  \
# 11907     1095       Ян   29          Тюмень              free  2,840.01
# 4002       431    Арина   18            Омск             ultra  4,119.21
# 4901       527  Арсений   30          Тюмень             ultra  3,225.82
# 9409       916    Арина   21  Ростов-на-Дону              free  2,773.05
# 14277     1263   Амалия   27    Екатеринбург              free  3,599.24
#
#        duration        date  month  minute_price  start_ride_price  \
# 11907     20.82  2021-05-11      5             8                50
# 4002      31.72  2021-12-28     12             6                 0
# 4901      17.19  2021-12-26     12             6                 0
# 9409      20.79  2021-07-24      7             8                50
# 14277     14.00  2021-06-07      6             8                50
#
#        subscription_fee
# 11907                 0
# 4002                199
# 4901                199
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# При использовании `sample` лучше фиксировать параметр `random_state`, так гарантируется, что и ты и заказчик увидите одни и теже данные)
# </div>

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
#  5   distance           18068 non-null  float64
#  6   duration           18068 non-null  float64
#  7   date               18068 non-null  object
#  8   month              18068 non-null  int64
#  9   minute_price       18068 non-null  int64
#  10  start_ride_price   18068 non-null  int64
#  11  subscription_fee   18068 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 1.8+ MB

# %%
print(f'в таблице users_go \033[1;30m{users_go.shape[0]}\033[0m строк и \033[1;30m{users_go.shape[1]}\033[0m столбцов\
        \nв таблице rides_go \033[1;30m{rides_go.shape[0]}\033[0m строк и \033[1;30m{rides_go.shape[1]}\033[0m столбцов\
        \nв таблице subscriptions_go \033[1;30m{subscriptions_go.shape[0]}\033[0m строк и \033[1;30m{subscriptions_go.shape[1]}\033[0m столбцов\
        \nв таблице full_df \033[1;30m{full_data.shape[0]}\033[0m строк и \033[1;30m{full_data.shape[1]}\033[0m столбцов')
# Out:
# в таблице users_go 1534 строк и 5 столбцов
# в таблице rides_go 18068 строк и 5 столбцов
# в таблице subscriptions_go 2 строк и 4 столбцов
# в таблице full_df 18068 строк и 12 столбцов

# %% [markdown]
# Далее создание двух датофреймов с пользователями с подпиской и без на основе общего датафрейма.

# %% [markdown]
# #### Создадим датафрейм с данными о пользователях без подписки

# %%
data_free = full_data.query('subscription_type == "free"')

# %%
# Просмотр результата data_free
data_free.head()
# Out:
#       user_id   name  age  city subscription_type  distance  duration  \
# 6500      700  Айдар   22  Омск              free  2,515.69     14.94
# 6501      700  Айдар   22  Омск              free    846.93     16.23
# 6502      700  Айдар   22  Омск              free  4,004.43     20.02
# 6503      700  Айдар   22  Омск              free  1,205.91      9.78
# 6504      700  Айдар   22  Омск              free  3,047.38     17.43
#
#             date  month  minute_price  start_ride_price  subscription_fee
# 6500  2021-01-02      1             8                50                 0
# 6501  2021-02-01      2             8                50                 0
# 6502  2021-02-04      2             8                50                 0
# 6503  2021-02-10      2             8                50                 0
# 6504  2021-02-14      2             8                50                 0

# %%
data_free.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11568 entries, 6500 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            11568 non-null  int64
#  1   name               11568 non-null  object
#  2   age                11568 non-null  int64
#  3   city               11568 non-null  object
#  4   subscription_type  11568 non-null  object
#  5   distance           11568 non-null  float64
#  6   duration           11568 non-null  float64
#  7   date               11568 non-null  object
#  8   month              11568 non-null  int64
#  9   minute_price       11568 non-null  int64
#  10  start_ride_price   11568 non-null  int64
#  11  subscription_fee   11568 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Создадим датафрейм с данными о пользователях c подпиской.

# %%
data_ultra = full_data.query('subscription_type == "ultra"')

# %%
# Просмотр результата data_ultra
data_ultra.head()
# Out:
#    user_id  name  age    city subscription_type  distance  duration  \
# 0        1  Кира   22  Тюмень             ultra  4,409.92     25.60
# 1        1  Кира   22  Тюмень             ultra  2,617.59     15.82
# 2        1  Кира   22  Тюмень             ultra    754.16      6.23
# 3        1  Кира   22  Тюмень             ultra  2,694.78     18.51
# 4        1  Кира   22  Тюмень             ultra  4,028.69     26.27
#
#          date  month  minute_price  start_ride_price  subscription_fee
# 0  2021-01-01      1             6                 0               199
# 1  2021-01-18      1             6                 0               199
# 2  2021-04-20      4             6                 0               199
# 3  2021-08-11      8             6                 0               199
# 4  2021-08-28      8             6                 0               199

# %%
data_ultra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6500 entries, 0 to 6499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            6500 non-null   int64
#  1   name               6500 non-null   object
#  2   age                6500 non-null   int64
#  3   city               6500 non-null   object
#  4   subscription_type  6500 non-null   object
#  5   distance           6500 non-null   float64
#  6   duration           6500 non-null   float64
#  7   date               6500 non-null   object
#  8   month              6500 non-null   int64
#  9   minute_price       6500 non-null   int64
#  10  start_ride_price   6500 non-null   int64
#  11  subscription_fee   6500 non-null   int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 660.2+ KB

# %%
print("Разница описательных значений столбцов с числовыми данными датафреймов 'data_free' и 'data_ultra'") 
data_free.describe() - data_ultra.describe()
# Out:
# Разница описательных значений столбцов с числовыми данными датафреймов 'data_free' и 'data_ultra'
#        user_id      age  distance  duration    month  minute_price  \
# count 5,068.00 5,068.00  5,068.00  5,068.00 5,068.00      5,068.00
# mean    771.80     0.00    -69.95     -1.15     0.10          2.00
# std      40.07    -0.28    409.28      0.75     0.04          0.00
# min     699.00     0.00   -243.35     -3.26     0.00          2.00
# 25%     740.00     0.00   -418.88     -1.57     0.00          2.00
# 50%     772.00     0.00    -33.99     -0.85     1.00          2.00
# 75%     803.00     0.00    345.12     -0.29     0.00          2.00
# max     835.00     5.00  1,511.24     -5.88     0.00          2.00
#
#        start_ride_price  subscription_fee
# count          5,068.00          5,068.00
# mean              50.00           -199.00
# std                0.00              0.00
# min               50.00           -199.00
# 25%               50.00           -199.00
# ...

# %% [markdown]
# **Промежуточный вывод:**
# - Общее количество. Поездок с исползьзованием подписки ‘free’ на 5068 больше, чем с использованием подписки ‘ultra’, и составляет 11568.
# - Возраст. Возрастные показатели пользователей с разным типом подписки в целом схожи, за исключением максимального возраста, который на 5 лет больше у пользователей с подпиской ‘free’.
# - Дистанция. Дистанция поездок при использовании подписки ‘free’ более разнообразна. Так максимальная дистанция больше на 1511 метров, а минимальная на 243 метра меньше, чем при использовании подписки ‘ultra’. Об этом же свидетельствует и стандартное отклонение, которое при использовании подписки ‘free’ больше на 409 метров, чем при использовании подписки ‘ultra’. Средняя дистанция при использовании подписки ‘free’ короче. Это следует из того, что среднее значениее на 70 метров, а медиана на 34 метра, меньше, чем при использовании ‘ultra’.
# - Продолжительность. Продолжительность поездок при использовании подписки ‘free’ немного меньше по всем показателям, чем при использовании ‘ultra’. Например, минимальное время меньше на 3.26 минут, а максимальное меньше на 5.88 минут.
# - Месяцы. Сезонность использования разного типа подписки схожа за исключением медианы, которая у подписчиков ‘ultra’ приходится на июнь, а у подписчиков ‘free’ на июль. При использовании обоих типов подписок наблюдаются спады пользовательской активности в феврале и ноябре.

# %% [markdown]
# #### Визуализация данных.

# %%
# Функция сравнения одинаковых столбцов 
# с количественными данными в разных датафреймах
def quantity_go_comparison(data1, data2, column, bins_num, xlabel, ylabel, title, dataname1, dataname2):
    print('Сравнение столбцов:', column)
    
    data1.rename(columns = {column:dataname1})[dataname1].plot.hist(
        bins=bins_num, 
        #xlim=(data_min, data_max),
        alpha=.5, 
        legend=True,
        grid=True
    )
    data2.rename(columns = {column:dataname2})[dataname2].plot.hist(
        bins=bins_num, 
        #xlim=(data_min, data_max),
        alpha=.5, 
        legend=True,
        grid=True
    )
    
    plt.gca().set(xlabel=f'${xlabel}$', ylabel=f'${ylabel}$')
    plt.title(f'{title}')
    plt.show()
    
    print(f"Описание датафрейма 'go_{dataname1}':")
    print(data1[column].describe().round(0))
    
    print(f"\nОписание датафрейма 'go_{dataname2}':")
    print(data2[column].describe().round(0))

# %%
# Функции сравнения одинаковых столбцов 
# с качественными данными в разных датафреймах
def quality_go_comparison(data1, data2, column, xlabel, ylabel, title, dataname1, dataname2, sort=False):
    print('Сравнение столбцов:', column)
    
    go_count = pd.DataFrame([
        data1.groupby(column)[column].agg('count'), 
        data2.groupby(column)[column].agg('count')
    ])
    go_count.index = [dataname1, dataname2]
    go_count = go_count.transpose()
    if sort == True:
        if go_count[dataname1].sum() >= go_count[dataname2].sum():
            go_count = go_count.sort_values(by=dataname1)
        else:
            go_count = go_count.sort_values(by=dataname2)
    
    go_count.plot.barh(grid=True)
    plt.gca().set(xlabel=f'${xlabel}$', ylabel=f'${ylabel}$')
    plt.title(f'{title}')
    plt.show()
    
    go_percent_sum = go_count[dataname1].sum() + go_count[dataname2].sum()
    go_percent = go_count / go_percent_sum
    
    print('Значения датафрейма:')
    print(go_count)
    print('\nРаспределение долей всего датафрейма:')
    print(go_percent)
    print('\nОписание датафрейма:')
    print(go_count.describe())

# %% [markdown]
# ##### Посмотрим количество использований сервиса в зависимости от возраста.

# %%
# Срвнение столбцов 'age' в 'data_ultra' и 'data_free'
quantity_go_comparison(
    data_ultra, 
    data_free, 
    'age', 
    int(data_free['age'].max()), 
    'Возраст', 
    'Количество_ использований_ сервиса', 
    'Количество использований сервиса в зависимости от возраста', 
    'ultra', 
    'free'
)
# Out:
# Сравнение столбцов: age
# Описание датафрейма 'go_ultra':
# count   6,500.00
# mean       25.00
# std         5.00
# min        12.00
# 25%        22.00
# 50%        25.00
# 75%        28.00
# max        38.00
# Name: age, dtype: float64
#
# Описание датафрейма 'go_free':
# count   11,568.00
# mean        25.00
# std          4.00
# min         12.00
# 25%         22.00
# 50%         25.00
# 75%         28.00
# max         43.00
# Name: age, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# * Отличное решение на одном графике отобразить оба тарифа
# * На графиках отлично смотрится среднее или медиана, как дополнительное опорной значение, вот [тут](https://stackoverflow.com/questions/16930328/vertical-horizontal-lines-in-matplotlib) можно посмотреть, как добавить такую визуализацию

# %% [markdown]
# **Промежуточный вывод:**
# <br>Возрастные показатели пользователей с разным типом подписки в целом схожи, за исключением максимального возраста, который на 5 лет больше у пользователей с подпиской ‘free’ и равен 43 годам.

# %% [markdown]
# ##### Посмотрим количество использований сервиса в зависимости от города.

# %%
# Срвнение столбцов 'city' в 'data_ultra' и 'data_free'
quality_go_comparison(
    data_ultra, 
    data_free, 
    'city', 
    'Город', 
    'Количество_ использований_ сервиса', 
    'Количество использований сервиса в зависимости от города', 
    'ultra', 
    'free',
    True
)
# Out:
# Сравнение столбцов: city
# Значения датафрейма:
#                 ultra  free
# city
# Москва            700  1175
# Омск              827  1250
# Тюмень            767  1354
# Сочи              813  1446
# Краснодар         780  1521
# Ростов-на-Дону    885  1565
# Екатеринбург      876  1585
# Пятигорск         852  1672
#
# Распределение долей всего датафрейма:
#                 ultra  free
# city
# Москва           0.04  0.07
# Омск             0.05  0.07
# Тюмень           0.04  0.07
# Сочи             0.04  0.08
# Краснодар        0.04  0.08
# Ростов-на-Дону   0.05  0.09
# Екатеринбург     0.05  0.09
# Пятигорск        0.05  0.09
#
# Описание датафрейма:
#        ultra     free
# count   8.00     8.00
# mean  812.50 1,446.00
# std    61.92   173.41
# min   700.00 1,175.00
# 25%   776.75 1,328.00
# 50%   820.00 1,483.50
# 75%   858.00 1,570.00
# max   885.00 1,672.00

# %% [markdown]
# **Промежуточный вывод:**
# <br>Во всех городах доминирует подписка ‘free’. Пятигорск является лидером по использованию этиго типа подписки (1672 поездок, это 9.25% от общего количества поездок). Ростов-на-Дону является лидером по использованию подписки ‘ultra’ (885 поездок, это 4.9% от общего количества поездок). Минимальное количество поездок совершено в Москве с использованием подписки ‘ultra’ (700 поездок, это 3.87% от общего количества поездок).

# %%
# Срвнение столбцов 'distance' в 'data_ultra' и 'data_free'
quantity_go_comparison(
    data_ultra, 
    data_free, 
    'distance', 
    int(data_free['distance'].max()/100), 
    'Расстояние', 
    'Количество_ использований_ сервиса', 
    'Количество использований сервиса в зависимости от расстояния поездки', 
    'ultra', 
    'free'
)
# Out:
# Сравнение столбцов: distance
# Описание датафрейма 'go_ultra':
# count   6,500.00
# mean    3,115.00
# std       837.00
# min       244.00
# 25%     2,785.00
# 50%     3,149.00
# 75%     3,561.00
# max     5,700.00
# Name: distance, dtype: float64
#
# Описание датафрейма 'go_free':
# count   11,568.00
# mean     3,045.00
# std      1,246.00
# min          1.00
# 25%      2,367.00
# 50%      3,115.00
# 75%      3,906.00
# max      7,211.00
# Name: distance, dtype: float64

# %% [markdown]
# **Промежуточный вывод:**
# <br>Дистанция поездок при использовании подписки ‘free’ более разнообразна. Так максимальная дистанция больше на 1511 метров, а минимальная на 243 метра меньше, чем при использовании подписки ‘ultra’. Об этом же свидетельствует и стандартное отклонение, которое при использовании подписки ‘free’ больше на 409 метров, чем при использовании подписки ‘ultra’. Средняя дистанция при использовании подписки ‘free’ короче. Это следует из того, что среднее значениее на 70 метров, а медиана на 34 метра, меньше, чем при использовании ‘ultra’.
#
# При использовании обоих подписок наблюдается два пика. Первый небольшой пик на меньших дистанциях и второй основной пик на больших дистанциях. Так меньший пик ‘ultra’ находится в районе 1000 метров, а основной в районе 3100 метров с небольшой коррекцией около 4000 метров. Меншьй пик ‘free’ в районе 700 метров, а основной 2500-3500 метров. В целом пики ‘ultra’ более выраженные и имеют меньший разрбос.

# %%
# Срвнение столбцов 'duration' в 'data_ultra' и 'data_free'
quantity_go_comparison(
    data_ultra, 
    data_free, 
    'duration', 
    int(data_free['duration'].max()), 
    'Продоложительность', 
    'Количество_ использований_ сервиса', 
    'Количество использований сервиса в зависимости от продолжительности поездки', 
    'ultra', 
    'free'
)
# Out:
# Сравнение столбцов: duration
# Описание датафрейма 'go_ultra':
# count   6,500.00
# mean       19.00
# std         6.00
# min         4.00
# 25%        15.00
# 50%        18.00
# 75%        22.00
# max        41.00
# Name: duration, dtype: float64
#
# Описание датафрейма 'go_free':
# count   11,568.00
# mean        17.00
# std          6.00
# min          0.00
# 25%         13.00
# 50%         17.00
# 75%         22.00
# max         35.00
# Name: duration, dtype: float64

# %% [markdown]
# **Промежуточный вывод:**
# <br>Продолжительность поездок при использовании подписки ‘free’ немного меньше по всем показателям, чем при использовании ‘ultra’. Например, минимальное время меньше на 3.26 минут, а максимальное меньше на 5.88 минут. В обоих случаях количество поездок относительно нормально распределено в зависимости от их продолжительности. Пик количества поездок приходится на 17-18 минут. При использовании подписки ‘free’ наблюдается пик в около 100 поездок с продолжительностью около 1 минуты.

# %%
# Срвнение столбцов 'month' в 'ultra_go' и 'free_go'
quality_go_comparison(
    data_ultra, 
    data_free, 
    'month', 
    'Месяц', 
    'Количество_ использований_ сервиса', 
    'Количество использований сервиса в зависимости от месяца', 
    'ultra', 
    'free',
)
# Out:
# Сравнение столбцов: month
# Значения датафрейма:
#        ultra  free
# month
# 1        584  1001
# 2        468   868
# 3        561   983
# 4        551   955
# 5        597   963
# 6        565   988
# 7        574   955
# 8        540   978
# 9        515  1002
# 10       529   946
# 11       492   926
# 12       524  1003
#
# Распределение долей всего датафрейма:
#        ultra  free
# month
# 1       0.03  0.06
# 2       0.03  0.05
# 3       0.03  0.05
# 4       0.03  0.05
# 5       0.03  0.05
# 6       0.03  0.05
# 7       0.03  0.05
# 8       0.03  0.05
# 9       0.03  0.06
# 10      0.03  0.05
# 11      0.03  0.05
# 12      0.03  0.06
#
# Описание датафрейма:
#        ultra     free
# count  12.00    12.00
# mean  541.67   964.00
# std    38.12    38.86
# min   468.00   868.00
# 25%   521.75   952.75
# 50%   545.50   970.50
# 75%   567.25   991.25
# max   597.00 1,003.00

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Спасибо за функцию, молодец, что стремишься к автоматизации повторяющихся задач

# %% [markdown]
# **Промежуточный вывод:**
# <br>Сезонность использования разного типа подписки схожа за исключением медианы, которая у подписчиков ‘ultra’ приходится на июнь, а у подписчиков ‘free’ на июль. При использовании обоих типов подписок наблюдаются спады пользовательской активности в феврале и ноябре. Максимум поездок с подпиской ‘ultra’ в мае (597 поездок, это 3.3% от всех поездок). Максимумы поездок с подпиской ‘free’ в январе (1001 поездка, это 5.54% от всех поездок), сентябре (1002 поездки) и декабре (1003 поездки). При использовании подписки ‘free’ нет выраженной сезонности, кроме спдов в феврале и ноябре. При использовании подписки ‘ultra’ наблюдается более выраженная сезонность. Количество поездок растет с февраля по май, а затем медленно снижается до ноября.

# %% [markdown]
# **Выводы из сравнения использования разных типов подписки:**
#
# - Общее количество. Поездок с исползьзованием подписки ‘free’ на 5068 больше, чем с использованием подписки ‘ultra’, и составляет 11568.
# - Возраст. Возрастные показатели пользователей с разным типом подписки в целом схожи, за исключением максимального возраста, который на 5 лет больше у пользователей с подпиской ‘free’.
# - Дистанция. Дистанция поездок при использовании подписки ‘free’ более разнообразна. Так максимальная дистанция больше на 1511 метров, а минимальная на 243 метра меньше, чем при использовании подписки ‘ultra’. Об этом же свидетельствует и стандартное отклонение, которое при использовании подписки ‘free’ больше на 409 метров, чем при использовании подписки ‘ultra’. Средняя дистанция при использовании подписки ‘free’ короче. Это следует из того, что среднее значениее на 70 метров, а медиана на 34 метра, меньше, чем при использовании ‘ultra’. При использовании обоих подписок наблюдается два пика. Первый небольшой пик на меньших дистанциях и второй основной пик на больших дистанциях. Так меньший пик ‘ultra’ находится в районе 1000 метров, а основной в районе 3100 метров с небольшой коррекцией около 4000 метров. Меншьй пик ‘free’ в районе 700 метров, а основной 2500-3500 метров. В целом пики ‘ultra’ более выраженные и имеют меньший разрбос.
# - Продолжительность. Продолжительность поездок при использовании подписки ‘free’ немного меньше по всем показателям, чем при использовании ‘ultra’. Например, минимальное время меньше на 3.26 минут, а максимальное меньше на 5.88 минут. В обоих случаях количество поездок относительно нормально распределено в зависимости от их продолжительности. Пик количества поездок приходится на 17-18 минут. При использовании подписки ‘free’ наблюдается пик в около 100 поездок с продолжительностью около 1 минуты.
# - Месяцы. Сезонность использования разного типа подписки схожа за исключением медианы, которая у подписчиков ‘ultra’ приходится на июнь, а у подписчиков ‘free’ на июль. При использовании обоих типов подписок наблюдаются спады пользовательской активности в феврале и ноябре. Максимум поездок с подпиской ‘ultra’ в мае (597 поездок, это 3.3% от всех поездок). Максимумы поездок с подпиской ‘free’ в январе (1001 поездка, это 5.54% от всех поездок), сентябре (1002 поездки) и декабре (1003 поездки). При использовании подписки ‘free’ нет выраженной сезонности, кроме спдов в феврале и ноябре. При использовании подписки ‘ultra’ наблюдается более выраженная сезонность. Количество поездок растет с февраля по май, а затем медленно снижается до ноября.
# - Города. Во всех городах доминирует подписка ‘free’. Пятигорск является лидером по использованию этиго типа подписки (1672 поездок). Ростов-на-Дону является лидером по использованию подписки ‘ultra’ (885 поездок).

# %% [markdown]
# ### Шаг 5. Подсчёт выручки

# %% [markdown]
# #### Создание датафрейма, агрегированного по пользователям.

# %% [markdown]
# Для каждого пользователя рассчитаем суммарное расстояние, количество поездок и суммарное время за каждый месяц

# %%
rev_data = (full_data
           .groupby(['user_id', 'month'])
           .agg(
               count = ('user_id','count'),
               distance = ('distance','sum'),
               duration=('duration', 'sum'),
               sub_type = ('subscription_type', 'first'))
            .reset_index()
)
rev_data
# Out:
#        user_id  month  count  distance  duration sub_type
# 0            1      1      2  7,027.51     41.42    ultra
# 1            1      4      1    754.16      6.23    ultra
# 2            1      8      2  6,723.47     44.78    ultra
# 3            1     10      2  5,809.91     31.58    ultra
# 4            1     11      3  7,003.50     53.40    ultra
# ...        ...    ...    ...       ...       ...      ...
# 11326     1534      6      2  3,409.47     24.81     free
# 11327     1534      8      2  7,622.45     47.21     free
# 11328     1534      9      1  4,928.17     22.56     free
# 11329     1534     11      4 13,350.02     76.34     free
# 11330     1534     12      1  2,371.71     15.89     free
#
# [11331 rows x 6 columns]

# %% [markdown]
# #### Добавление столбца в агрегированный датафрейм с помесячной выручкой по каждому пользователю.

# %%
# Округлим продолжительность поездок до целого числа
rev_data['duration'] = np.ceil(rev_data['duration'])
rev_data['duration']
# Out:
# 0       42.00
# 1        7.00
# 2       45.00
# 3       32.00
# 4       54.00
#          ...
# 11326   25.00
# 11327   48.00
# 11328   23.00
# 11329   77.00
# 11330   16.00
# Name: duration, Length: 11331, dtype: float64

# %%
# Расчет выручки
rev_data['revenue'] = (
    np.select(
        condlist=[rev_data['sub_type']=='free',rev_data['sub_type']=='ultra'],
        choicelist = [50* rev_data['count'] + 8 * rev_data['duration'], 6*rev_data['duration']+199],
        default = 0)
)
rev_data
# Out:
#        user_id  month  count  distance  duration sub_type  revenue
# 0            1      1      2  7,027.51     42.00    ultra   451.00
# 1            1      4      1    754.16      7.00    ultra   241.00
# 2            1      8      2  6,723.47     45.00    ultra   469.00
# 3            1     10      2  5,809.91     32.00    ultra   391.00
# 4            1     11      3  7,003.50     54.00    ultra   523.00
# ...        ...    ...    ...       ...       ...      ...      ...
# 11326     1534      6      2  3,409.47     25.00     free   300.00
# 11327     1534      8      2  7,622.45     48.00     free   484.00
# 11328     1534      9      1  4,928.17     23.00     free   234.00
# 11329     1534     11      4 13,350.02     77.00     free   816.00
# 11330     1534     12      1  2,371.71     16.00     free   178.00
#
# [11331 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>☁️
#
# Необходимо ведь было округление перед подсчетом дохода
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №1:</b>
# <br>Добавил блок "Округлим продолжительность поездок до целого числа"
# <br>Значения округлились.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера v2:</b>⛅️
#
# Округление было бы точнее добавить перед агрегацией на этапе датафрейма `full_data`.
#
#
# Желаю успехов в дальнейшем обучении
# </div>

# %%
print('Годовая выручка по подписке:', rev_data[rev_data['sub_type']=='ultra']['revenue'].sum())
print('Годовая выручка без подписки:', rev_data[rev_data['sub_type']=='free']['revenue'].sum())
# Out:
# Годовая выручка по подписке: 1638597.0
# Годовая выручка без подписки: 2215080.0

# %% [markdown]
# **Промежуточный вывод:**
# <br>Создали новый датафрейм с агрегированными данными ("rev_data") на основе датафрейма "full_data" с объединенными данными.
# <br>Нашли суммарное расстояние, количество поездок и суммарное время для каждого пользователя за каждый месяц.
# <br>Также добавили столбец с помесячной выручкой, которую принес каждый пользователь.
# * Годовая выручка по подписке: **1638597 руб.**
# * Годовая выручка без подписки: **2215080 руб.**

# %% [markdown]
# ### Шаг 6. Проверка гипотез

# %% [markdown]
# #### Важно понять, тратят ли пользователи с подпиской больше времени на поездки?

# %% [markdown]
# Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.
# <br>Нулевая и альтернативная гипотезы:
# - Гипотеза Н0: Средняя продолжительность поездок с подпиской ‘ultra’ и ‘free’ равна.
# - Гипотеза Н1: Средняя продолжительность поездок с подпиской ‘ultra’ меньше, чем с подпиской ‘free’.

# %%
ultra = data_ultra['duration'] 

free = data_free['duration']

results = st.ttest_ind(ultra, 
                       free,
                       alternative = 'greater')

alpha = .05

print(results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 1.2804098316645618e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Отлично, что формулируешь нулевую, альтернативную гипотезу, это важно, выводы верны, ещё могу порекомендовать дополнительно проверять себя и выводить среднее проверяемых переменных или распределения

# %%
ax = sns.barplot(x = 'month',
            y = 'duration',
            hue = "subscription_type",
            data = full_data,
            palette = ['green', 'blue'])
ax.set_title('Распределение продолжительности поездок по видам подписок и месяцам')
ax.set(xlabel='Номер месяца', ylabel='Продолжительность поездок');

# %% [markdown]
# **Промежуточный вывод:**
# <br>Проверили гипотезу, отвергли гипотезу о том, что время поездки пользователей на тарифе `ultra` равно времени поездки пользователей на тарифе `free`.

# %% [markdown]
# ####  Расстояние, которое проежают пользователи с подпиской за одну поездку, не привышает 3130 метров?

# %% [markdown]
# 3130 метров — оптимальное расстояние с точки зрения износа самоката.
# <br>Нулевая и альтернативная гипотезы:
# - Гипотеза Н0: Среднее расстояние поездок с использованием подписки ‘ultra’ равно оптимальному расстоянию в 3130 метров.
# - Гипотеза Н1: Среднее расстояние поездок с использованием подписки ‘ultra’ более 3130 метров.

# %%
distance_ultra = data_ultra['distance']

alpha = 0.05

interested_value = 3130

results = st.ttest_1samp(distance_ultra, interested_value, alternative = 'greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.9195368847849785
# Не получилось отвергнуть нулевую гипотезу

# %%
print('Средняя дистанция поездки по подписке:', round(data_ultra['distance'].mean(),2), 'м.')
# Out:
# Средняя дистанция поездки по подписке: 3115.45 м.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Бизнес может спать спокойно, спасибо, что дополнительно вывел среднюю дистанцию поездок

# %% [markdown]
# **Промежуточный вывод:**
# <br>Расстояние, которое проезжают пользователи **с подпиской** за одну поездку, не превышает 3130 метров.

# %% [markdown]
# #### Помесячная выгрузка от пользователей с подпиской выше, чем выручка от пользователей без подписки? Сделать выводы.

# %% [markdown]
# Нулевая и альтернативная гипотезы:
# - Гипотеза Н0: Средняя выручка от поездок с разной подпиской равна.
# - Гипотеза Н1: Средняя выручка от поездок с использованием подписки ‘ultra’ меньше, чем выручка с ипользованием подписки ‘free’.

# %%
revenue_free = rev_data.query('sub_type ==  "free"')['revenue']
revenue_ultra = rev_data.query('sub_type == "ultra"')['revenue']

alpha = 0.05

results = st.ttest_ind(revenue_ultra, revenue_free, alternative = 'greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.8130926188487286e-35
# Отвергаем нулевую гипотезу

# %%
print('Средняя выручка за месяц(с подпиской):', round(rev_data[rev_data['sub_type'] =="ultra"]["revenue"].mean()),'руб.')
print('Средняя выручка за месяц(без подписки):', round(rev_data[rev_data['sub_type'] =="free"]["revenue"].mean()),'руб.')
# Out:
# Средняя выручка за месяц(с подпиской): 361 руб.
# Средняя выручка за месяц(без подписки): 326 руб.

# %% [markdown]
# **Промежуточный вывод:**
# <br>Помесячная выручка от пользователей **с подпиской** больше чем от пользователей **без подписки.**

# %% [markdown]
# #### Каким тестом проверить гипотезу о снижении количества  пользовательских обращений после обновления сервиса, с которым взоимодействует мобильное приложение?

# %% [markdown]
# Сначала требуется провести сравнение выборок на предмет соответствия уникальных пользователей в них.
#
# - Если списки уникальных пользователей в них совпадают, то выборки зависимы и для проверки гипотезы потребуется тест st.ttest_rel(before, after, alternative=’less’)
#
# - В ином случае, выборки не могут быть зависимы и для проверки гипотезы потребуется тест: st.ttest_ind(before, after, equal_var=False, alternative=’less’). Где, equal_var=False, т.к. выборки не равны, а alternative=’less’, т.к. основная гипотеза отвергается, если изначально обращений было меньше, чем после обновлений сервиса.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Отлично, что говоришь о зависимости выборок, односторонней альтернативной гипотезе

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Все исходные данные во всех файлах не содержали пропусков, значительных выбросов, а также дубликатов, кроме тех, которые были обнаружены в файле ‘users_go.csv’. При копировании данных из файлов в датафреймы, данные столбцов были не в оптимальном состоянии. В ходе предобработки данных они были оптимизированы для целей данного проекта.
#
# <br>**В ходе исследовательского анализа данных было выявлено:**
#
# - Пользователей с подпиской «free» всего 835, что составляет 54.43% от общего количества и на 136 больше, чем с подпиской «ultra».
# - Услугами сервиса аренды самокатов пользуются люди от 12 до 43 лет. Максимальное количество пользователей в возрасте 25 лет, этот же возраст является медианным.
# - Большая часть всех пользователей используют подписку «free». Всего их 835, что составляет 54.43% от общего количества и на 136 больше, чем с подпиской «ultra».
# - Максимальное количество в 219 поездок совершено в Пятигорске. Минимальное количество в 168 поездок совершено в Москве.
# - За одну поездку пользователи преодолевают от 1 до 7211 метров. Медиана всех значений равна 3134 метров. Наблюдаются два пика. Малый пик около 700 метров, большой пик около 3200 метров. Между пиками значения нормально распределены.
# - Продолжительность поездок нормально распределена от 0 до 41 минуты. Продолжительность в 18 минут является как наиболее распространенной так и медианным значением. Наблюдается выброс размером менее 100 поездок с продолжительностью в 1 минуту.
#
# <br>**В результате группировки данных выявлено:**
#
# - Поездок с исползьзованием подписки ‘free’ на 5068 больше, чем с использованием подписки ‘ultra’, и составляет 11568.
# - Возрастные показатели пользователей с разным типом подписки в целом схожи, за исключением максимального возраста, который на 5 лет больше у пользователей с подпиской ‘free’.
# - Дистанция поездок при использовании подписки ‘free’ более разнообразна. Так максимальная дистанция больше на 1511 метров, а минимальная на 243 метра меньше, чем при использовании подписки ‘ultra’. Об этом же свидетельствует и стандартное отклонение, которое при использовании подписки ‘free’ больше на 409 метров, чем при использовании подписки ‘ultra’. Средняя дистанция при использовании подписки ‘free’ короче. Это следует из того, что среднее значениее на 70 метров, а медиана на 34 метра, меньше, чем при использовании ‘ultra’. При использовании обоих подписок наблюдается два пика. Первый небольшой пик на меньших дистанциях и второй основной пик на больших дистанциях. Так меньший пик ‘ultra’ находится в районе 1000 метров, а основной в районе 3100 метров с небольшой коррекцией около 4000 метров. Меншьй пик ‘free’ в районе 700 метров, а основной 2500-3500 метров. В целом пики ‘ultra’ более выраженные и имеют меньший разрбос.
# - Продолжительность поездок при использовании подписки ‘free’ немного меньше по всем показателям, чем при использовании ‘ultra’. Например, минимальное время меньше на 3.26 минут, а максимальное меньше на 5.88 минут. В обоих случаях количество поездок относительно нормально распределено в зависимости от их продолжительности. Пик количества поездок приходится на 17-18 минут. При использовании подписки ‘free’ наблюдается пик в около 100 поездок с продолжительностью около 1 минуты.
# - Сезонность использования разного типа подписки схожа за исключением медианы, которая у подписчиков ‘ultra’ приходится на июнь, а у подписчиков ‘free’ на июль. При использовании обоих типов подписок наблюдаются спады пользовательской активности в феврале и ноябре. Максимум поездок с подпиской ‘ultra’ в мае (597 поездок, это 3.3% от всех поездок). Максимумы поездок с подпиской ‘free’ в январе (1001 поездка, это 5.54% от всех поездок), сентябре (1002 поездки) и декабре (1003 поездки). При использовании подписки ‘free’ нет выраженной сезонности, кроме спдов в феврале и ноябре. При использовании подписки ‘ultra’ наблюдается более выраженная сезонность. Количество поездок растет с февраля по май, а затем медленно снижается до ноября.
# - Во всех городах доминирует подписка ‘free’. Пятигорск является лидером по использованию этиго типа подписки (1672 поездок). Ростов-на-Дону является лидером по использованию подписки ‘ultra’ (885 поездок).
#
# - **В ходе рассмотрения гиптез:**
#
#    **Пользователи с подпиской тратят больше времени на поездки.**
#
#   * Гипотеза подтвердилась
#   * Средняя продолжительность поездок с подпиской: **19.04 мин.**
#   * Средняя продолжительность поездок без подписки: **18.03 мин.**
#
# **Среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров.**
#
#    * Гипотеза подтвердилась
#    * Средняя дистанция поездки по подписке: **3115.45 м.**
#
# **Помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.**
#
#    * Гипотеза подтвердилась
#    * Средняя выручка за месяц(с подпиской): **359 руб.**
#    * Средняя выручка за месяц(без подписки): **322 руб.**

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Замечательный вывод, спасибо, что выделяешь какие-то фрагменты дополнительно. Пару аспектов хочется с тобой обсудить, жду повторной отправки проекта тобой
